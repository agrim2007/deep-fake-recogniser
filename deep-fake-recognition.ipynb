# %%
import os
import pandas as pd
import numpy as np
import librosa
from tqdm import tqdm

# %%
df = pd.read_csv("meta.csv")

# %%
df.sample(5)
# Out:
#             file            speaker      label
# 15629  15629.wav          Bill Burr  bona-fide
# 28243  28243.wav      Alec Guinness  bona-fide
# 4250    4250.wav       Barack Obama  bona-fide
# 19780  19780.wav      Ronald Reagan      spoof
# 26735  26735.wav  Winston Churchill  bona-fide

# %%
df = df.drop("speaker",axis = 1)

# %%
df.sample(5)
# Out:
#             file      label
# 18424  18424.wav  bona-fide
# 20600  20600.wav      spoof
# 29240  29240.wav      spoof
# 13867  13867.wav  bona-fide
# 26587  26587.wav  bona-fide

# %%
label_mapping = {'bona-fide': 0, 'spoof': 1}
df['label_code'] = df['label'].map(label_mapping)

# %%
df.sample(5)
# Out:
#             file      label  label_code
# 11125  11125.wav      spoof           1
# 2335    2335.wav  bona-fide           0
# 16145  16145.wav      spoof           1
# 30134  30134.wav      spoof           1
# 13276  13276.wav  bona-fide           0
